# %%
import pandas as pd

# %%
df_1 = pd.read_csv('../datasets/RTA_Datasest_Cleaned_newPrepro.csv')
df_2 = pd.read_csv('../datasets/rta_Cleanfix.csv')

# %%
df_1
# Out:
#            Time        Day Age_band_of_driver Sex_of_driver  \
# 0      17:00:00     Monday              18-30          Male
# 1      17:00:00     Monday              31-50          Male
# 2      17:00:00     Monday              18-30          Male
# 3      01:00:00     Sunday              18-30          Male
# 4      01:00:00     Sunday              18-30          Male
# ...         ...        ...                ...           ...
# 12311  16:00:00  Wednesday              31-50          Male
# 12312  18:00:00     Sunday            Unknown          Male
# 12313  13:00:00     Sunday            Over 51          Male
# 12314  13:00:00     Sunday              18-30        Female
# 12315  13:00:00     Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df_2['Light_conditions'].value_counts()
# Out:
# Light_conditions
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: count, dtype: int64

# %%
df_1
# Out:
#            Time        Day Age_band_of_driver Sex_of_driver  \
# 0      17:00:00     Monday              18-30          Male
# 1      17:00:00     Monday              31-50          Male
# 2      17:00:00     Monday              18-30          Male
# 3      01:00:00     Sunday              18-30          Male
# 4      01:00:00     Sunday              18-30          Male
# ...         ...        ...                ...           ...
# 12311  16:00:00  Wednesday              31-50          Male
# 12312  18:00:00     Sunday            Unknown          Male
# 12313  13:00:00     Sunday            Over 51          Male
# 12314  13:00:00     Sunday              18-30        Female
# 12315  13:00:00     Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df_2
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday             Dewasa          Male
# 1      17:02:00      Monday             Dewasa          Male
# 2      17:02:00      Monday             Dewasa          Male
# 3       1:06:00      Sunday             Dewasa          Male
# 4       1:06:00      Sunday             Dewasa          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday             Dewasa          Male
# 12312  18:00:00      Sunday            Unknwon          Male
# 12313  13:55:00      Sunday             Lansia          Male
# 12314  13:55:00      Sunday             Dewasa        Female
# 12315  13:55:00      Sunday             Dewasa          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df_1['Light_conditions']
# Out:
# 0                     Daylight
# 1                     Daylight
# 2                     Daylight
# 3        Darkness - lights lit
# 4        Darkness - lights lit
#                  ...
# 12311                 Daylight
# 12312                 Daylight
# 12313                 Daylight
# 12314    Darkness - lights lit
# 12315    Darkness - lights lit
# Name: Light_conditions, Length: 12316, dtype: object

# %%
df_2['Light_conditions']
# Out:
# 0                     Daylight
# 1                     Daylight
# 2                     Daylight
# 3        Darkness - lights lit
# 4        Darkness - lights lit
#                  ...
# 12311                 Daylight
# 12312                 Daylight
# 12313                 Daylight
# 12314    Darkness - lights lit
# 12315    Darkness - lights lit
# Name: Light_conditions, Length: 12316, dtype: object

# %%
df_2.drop(columns=['Defect_of_vehicle'], axis=1,inplace=
          True)
df_1.drop(columns=['Work_of_casuality'], axis=1, inplace=True)

# %%
# df_2.drop(columns='Defect_of_vehicle',axis=1, inplace=True)

# %%
columns_to_replace = [
    "Time",
    # "Day_of_week",
    "Sex_of_driver",
    "Educational_level",
    "Vehicle_driver_relation",
    "Driving_experience",
    "Owner_of_vehicle",
    "Service_year_of_vehicle",  
    # "Defect_of_vehicle",
    "Area_accident_occured",
    "Type_of_collision",
    "Road_surface_type",
    "Light_conditions",
    "Weather_conditions",
    "Vehicle_movement",
    # "Casualty_class"
]

# Misalnya mengganti kolom tertentu di dataset 2 dengan dataset 1, berdasarkan urutan baris
for col in columns_to_replace:
    df_2[col] = df_1[col]

# Hasil gabungan adalah dataset_2 yang telah diperbarui

# %%
columns_to_drop = [col for col in df_2.columns if col not in df_1.columns]

df_2.drop(columns=columns_to_drop, inplace=True)
print(df_2)
# Out:
#            Time Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      17:00:00             Dewasa          Male   Above high school
# 1      17:00:00             Dewasa          Male  Junior high school
# 2      17:00:00             Dewasa          Male  Junior high school
# 3      01:00:00             Dewasa          Male  Junior high school
# 4      01:00:00             Dewasa          Male  Junior high school
# ...         ...                ...           ...                 ...
# 12311  16:00:00             Dewasa          Male  Junior high school
# 12312  18:00:00            Unknwon          Male   Elementary school
# 12313  13:00:00             Lansia          Male  Junior high school
# 12314  13:00:00             Dewasa        Female  Junior high school
# 12315  13:00:00             Dewasa          Male  Junior high school
#
#       Vehicle_driver_relation Driving_experience     Type_of_vehicle  \
# ...

# %%
df_2
# Out:
#            Time Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      17:00:00             Dewasa          Male   Above high school
# 1      17:00:00             Dewasa          Male  Junior high school
# 2      17:00:00             Dewasa          Male  Junior high school
# 3      01:00:00             Dewasa          Male  Junior high school
# 4      01:00:00             Dewasa          Male  Junior high school
# ...         ...                ...           ...                 ...
# 12311  16:00:00             Dewasa          Male  Junior high school
# 12312  18:00:00            Unknwon          Male   Elementary school
# 12313  13:00:00             Lansia          Male  Junior high school
# 12314  13:00:00             Dewasa        Female  Junior high school
# 12315  13:00:00             Dewasa          Male  Junior high school
#
#       Vehicle_driver_relation Driving_experience     Type_of_vehicle  \
# ...

# %%
df_2['Day']
# Out:
# 0           Monday
# 1           Monday
# 2           Monday
# 3           Sunday
# 4           Sunday
#            ...
# 12311    Wednesday
# 12312       Sunday
# 12313       Sunday
# 12314       Sunday
# 12315       Sunday
# Name: Day, Length: 12296, dtype: object

# %%
df_2['Casualty_severity'].value_counts()
# Out:
# Casualty_severity
# 3          7064
# unknown    4435
# 2           771
# 1            26
# Name: count, dtype: int64

# %%
df_2.to_csv('../datasets/cleanedfix.csv', index = False)

# %%
import pandas as pd
from dython.nominal import associations

complete_correlation = associations(df_2, filename=None, figsize=(10,10))

df_complete_corr = complete_correlation['corr']
filtered_corr = df_complete_corr[df_complete_corr.abs() > 0.1]
filtered_corr = filtered_corr.reset_index()

# Cetak hasil
print(filtered_corr)
# Out:
#                           index      Time  Age_band_of_driver  Sex_of_driver  \
# 0                          Time  1.000000                 NaN            NaN
# 1            Age_band_of_driver       NaN            1.000000       0.359335
# 2                 Sex_of_driver       NaN            0.359335       1.000000
# 3             Educational_level       NaN                 NaN            NaN
# 4       Vehicle_driver_relation       NaN                 NaN            NaN
# 5            Driving_experience       NaN                 NaN            NaN
# 6               Type_of_vehicle       NaN                 NaN            NaN
# 7              Owner_of_vehicle       NaN                 NaN            NaN
# 8       Service_year_of_vehicle       NaN                 NaN            NaN
# 9         Area_accident_occured       NaN                 NaN            NaN
# 10             Lanes_or_Medians       NaN                 NaN            NaN
# ...

# %%
df_2.isnull().sum()
# Out:
# Time                           0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Fitness_of_casuality           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# ...

# %%
df_2['Day'] = df_1['Day']

# %%
df_2
# Out:
#            Time Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      17:00:00             Dewasa          Male   Above high school
# 1      17:00:00             Dewasa          Male  Junior high school
# 2      17:00:00             Dewasa          Male  Junior high school
# 3      01:00:00             Dewasa          Male  Junior high school
# 4      01:00:00             Dewasa          Male  Junior high school
# ...         ...                ...           ...                 ...
# 12311  16:00:00             Dewasa          Male  Junior high school
# 12312  18:00:00            Unknwon          Male   Elementary school
# 12313  13:00:00             Lansia          Male  Junior high school
# 12314  13:00:00             Dewasa        Female  Junior high school
# 12315  13:00:00             Dewasa          Male  Junior high school
#
#       Vehicle_driver_relation Driving_experience     Type_of_vehicle  \
# ...

# %%
df_1['Light_conditions'].value_counts()
# Out:
# Light_conditions
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - lights unlit     232
# Name: count, dtype: int64

# %%
df_2['Light_conditions']  = df_1['Light_conditions']

# %%
df_2['Light_conditions'].value_counts()
# Out:
# Light_conditions
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - lights unlit     232
# Name: count, dtype: int64

# %%
df_2['Type_of_collision']
# Out:
# 0        Stationary Object Collision
# 1                  Vehicle Collision
# 2        Stationary Object Collision
# 3                  Vehicle Collision
# 4                  Vehicle Collision
#                     ...
# 12311              Vehicle Collision
# 12312              Vehicle Collision
# 12313              Vehicle Collision
# 12314              Vehicle Collision
# 12315              Vehicle Collision
# Name: Type_of_collision, Length: 12316, dtype: object

# %%
df_2['Vehicle_movement']
# Out:
# 0        Moving forward
# 1        Moving forward
# 2        Moving forward
# 3        Moving forward
# 4        Moving forward
#               ...
# 12311    Moving forward
# 12312             Other
# 12313             Other
# 12314             Other
# 12315          Stopping
# Name: Vehicle_movement, Length: 12316, dtype: object

# %%
df_2['Area_accident_occured'] = df_2['Area_accident_occured'].str.strip()

# %%
df_2['Area_accident_occured'].value_counts()
# Out:
# Area_accident_occured
# Other                              4058
# Office areas                       3451
# Residential areas                  2060
# Church areas                       1060
# Industrial areas                    456
# School areas                        415
# Recreational areas                  328
# Outside rural areas                 218
# Hospital areas                      121
# Market areas                         63
# Rural village areas                  44
# Unknown                              22
# Rural village areasOffice areas      20
# Name: count, dtype: int64

# %%
df_2.isnull().sum()
# Out:
# Time                             0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle                 0
# Service_year_of_vehicle          0
# Area_accident_occured            0
# Lanes_or_Medians                 0
# Road_allignment                509
# Types_of_Junction                0
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement                 0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Fitness_of_casuality             0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
df_2.drop(df_2[df_2['Area_accident_occured'] == 'Rural village areasOffice areas'].index, axis=0, inplace=True)

print(df_2['Area_accident_occured'].value_counts())
# Out:
# Area_accident_occured
# Other                  4058
# Office areas           3451
# Residential areas      2060
# Church areas           1060
# Industrial areas        456
# School areas            415
# Recreational areas      328
# Outside rural areas     218
# Hospital areas          121
# Market areas             63
# Rural village areas      44
# Unknown                  22
# Name: count, dtype: int64

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12296 entries, 0 to 12315
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12296 non-null  object
#  1   Age_band_of_driver           12296 non-null  object
#  2   Sex_of_driver                12296 non-null  object
#  3   Educational_level            12296 non-null  object
#  4   Vehicle_driver_relation      12296 non-null  object
#  5   Driving_experience           12296 non-null  object
#  6   Type_of_vehicle              12296 non-null  object
#  7   Owner_of_vehicle             12296 non-null  object
#  8   Service_year_of_vehicle      12296 non-null  object
#  9   Area_accident_occured        12296 non-null  object
#  10  Lanes_or_Medians             12296 non-null  object
#  11  Road_allignment              11787 non-null  object
#  12  Types_of_Junction            12296 non-null  object
# ...

# %%
df_2['Road_allignment'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_6758/860231632.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2['Road_allignment'].fillna('Unknown', inplace=True)

# %%
df_2.isnull().sum()
# Out:
# Time                           0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Fitness_of_casuality           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# ...
